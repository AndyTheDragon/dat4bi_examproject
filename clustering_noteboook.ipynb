# %%
import pandas as pd
from ShowClustering import (
    meanshift_diagrams,
    kmeans_elbow_diagram,
    kmeans_silhouette_diagram,
    kmeans_cluster_plots,
    yellowbrick_silhouette_diagram,
)

df = pd.read_csv(r'data/cleaned_sales_data.csv')

# MeanShift
ms_res = meanshift_diagrams(df, quantile=0.3)

# KMeans selection helpers
kmeans_elbow_diagram(df, k_range=range(2, 12))
kmeans_silhouette_diagram(df, k_range=range(2, 12))

# Final KMeans and cluster plots
km_res = kmeans_cluster_plots(df, n_clusters=5)

# Yellowbrick (optional)
yellowbrick_silhouette_diagram(df, k=5)
# Out:
# K=2: silhouette=0.935
# K=3: silhouette=0.248
# K=4: silhouette=0.267
# K=5: silhouette=0.277
# K=6: silhouette=0.267
# K=7: silhouette=0.273
# K=8: silhouette=0.272
# K=9: silhouette=0.201
# K=10: silhouette=0.209
# K=11: silhouette=0.208
# KMeans(n_clusters=5, n_init=10, random_state=42)
